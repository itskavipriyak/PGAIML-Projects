# %% [markdown]
# #### > Import below libraries and proceed <

# %%
import numpy       as np
import pandas      as pd
import scipy.stats as stats
from scipy.stats             import ttest_1samp,ttest_ind, wilcoxon
from statsmodels.stats.power import ttest_power
import matplotlib.pyplot     as     plt

# %% [markdown]
# | Question No. | Marks | Total |
# |  -------- | ----- | ---- |
# | Q1- Q5 | 1 Mark each | 5 Marks |
# | Q6- Q10 | 2 Mark each | 10 Marks |
# | Total | --------------> | 15 Marks|

# %% [markdown]
# ## <font color ='Dark '>Q1- Q3 Description-  The data collected by an Advertisement agency has revealed that out of 2800 visitors, 56 visitors clicked on 1 Advertisement, 30 clicked on 2 advertisements and 14 clicked on 3 advertisements and the remaining did not click on any advertisement.</font>

# %% [markdown]
# ## Calculate
#
# ### Q1 The probability that a visitor to the website will not click on any advertisement.
# (1 Mark)

# %%
# Probability of NO event will be P = (Total customers - number of customers who click any advertisement) / Total customers
p=2800-(56+30+14)
p=p/2800
print("Probability of visitors to the website who dont click any advertisment: ", round(p,4))
# Out:
# Probability of visitors to the website who dont click any advertisment:  0.9643

# %% [markdown]
# ### Q2 The probability that a visitor to the website will click on an advertisement.
# (1 Mark)

# %%
# Probability of All events will be P=(Number of customers who click any advertisement) / Total Customers
p=(56+30+14) / 2800
print("Probability of visitors who click on any advertisement : ",round(p,4))
# Out:
# Probability of visitors who click on any advertisement :  0.0357

# %% [markdown]
# ### Q3 The probability that a visitor to the website will click on more than one advertisement.
# (1 Mark)

# %%
# Probability of multiple events will be P=(Number of customers click 2 or 3 advertisement) / Total Customers
p=(30+14) / 2800
print("Probability of visitors who will click more than 1 advertisement : ", round(p,4))
# Out:
# Probability of visitors who will click more than 1 advertisement :  0.0157

# %% [markdown]
# ## <font color ='Dark '> Q4 -5 Description - At a popular company service center, a total of 100 complaints were received. 80 customers complained about late delivery of the items and 60 complained about poor product quality.
# </font>

# %% [markdown]
# ### Q4 Calculate the probability that a customer complaint will be about both product quality and late delivery.
# (1 Mark)

# %%
# Apply intersection of probability A and probability of B - P(A n B ) = P(A)+P(B)-P(A U B)
p=(80+60)-100
p=p/100
print ("Probability of customers who will complaint both product quality and late delivery : ",p)
# Out:
# Probability of customers who will complaint both product quality and late delivery :  0.4

# %% [markdown]
# ### Q5 - What is the probability that a complaint will be only about late delivery?
# (1 Mark)

# %%
# P( only A) = P(A) - P(A n B)
# From Q4 - P(A n B) is 0.4
pa=(80/100)
pa=pa-0.4
print ("Probability of customers who will complaint only late delivery : ",pa)
# Out:
# Probability of customers who will complaint only late delivery :  0.4

# %% [markdown]
# ### Q6 You are given the daily sugar intake of 11 diabetic patients in the following Python code. Is there any evidence to the claim that the average daily sugar intake of the diabetic patients is 7600 mg.
# (2 Marks)
#
# * Hint: Use t test

# %%
# daily intake of Sugar in milligrams for 11 diabetic patients

daily_intake = np.array([5560, 5770, 7640, 5180, 5690, 6435, 6803, 7689, 6876, 8213, 8765])
stat, pvalue=stats.ttest_1samp(daily_intake,7600)
print(pvalue)
# Out:
# 0.04481624562570511

# %%
print("Since P value is less than 0.05, this can be rejected as null hypothesis")
# Out:
# Since P value is less than 0.05, this can be rejected as null hypothesis

# %% [markdown]
# ## <font color ='Dark '>Q7-Q8 Description Write the null and alternative hypothesis from the following hypopthesis description:</font>

# %% [markdown]
# ### Q7Average annual salary of Data Scientists is different for those having Ph.D in Statistics and those who do not.
# (2 Marks)
# * Let $\mu_{PhD}$ be the average annual salary of a Data scientist with Ph.D in Statistics.
# * Let $\mu_{NoPhD}$ be the average annual salary of a Data scientist without Ph.D in Statistics.

# %%
Null Hypothesis(Ho):
    𝜇𝑃ℎ𝐷=𝜇𝑁𝑜𝑃ℎ𝐷
    (or)
    (𝜇𝑃ℎ𝐷 - 𝜇𝑁𝑜𝑃ℎ𝐷) = 0
    
Alternate Hypothesis(Ha):
    𝜇𝑃ℎ𝐷 != 𝜇𝑁𝑜𝑃ℎ𝐷
    (or)
    (𝜇𝑃ℎ𝐷 - 𝜇𝑁𝑜𝑃ℎ𝐷) != 0

# %% [markdown]
# ### Q8 Average annual salary of Data Scientists is more for those having Ph.D in Statistics and those who do not.
# (2 Marks)

# %%
Null Hypothesis: 
    𝜇𝑃ℎ𝐷 <= 𝜇𝑁𝑜𝑃ℎ𝐷
    
Alternate Hypothesis
    𝜇𝑃ℎ𝐷 > 𝜇𝑁𝑜𝑃ℎ𝐷

# %% [markdown]
# ### Q9 - Compare the following two unrelated samples. Data was collected on the weight of women and men enrolled in a weight reduction program. At 𝛼 α = 0.05, test whether the weight of these two samples is different.
# (2 Marks)

# %%
Weight_Female       =  [ 53.8, 54.4, 51.2, 52.5, 61.0, 50.6, 51.6, 70.0]
Weight_Male         =  [ 72.5, 80.3, 71.3, 67.7, 66.2, 73.4, 61.3, 76.8]

# %% [markdown]
# NULL HYPOTHSIS MALE AND FEMALE WEIGHT IS EQUAL.
#
# ALTERNATE HYPOTHESIS MALE AND FEMALE WEIGHT IS DIFFERENT.
#
# OUR CONDITION IS TO PROVE THAT WEIGHT OF THE MALE AND FEMALE ARE NOT EQUAL SO,WE REQUIRE ALTERNATE HYPOTHESIS.

# %%
tstat,pvalue=stats.ttest_ind(Weight_Female,Weight_Male)
print("P Value of ttest : ",pvalue)
# Out:
# P Value of ttest :  0.00024034957515992796

# %%
print("Since P value is 0 and Alpha is 0.05, this is rejected as Null hypothesis")
# Out:
# Since P value is 0 and Alpha is 0.05, this is rejected as Null hypothesis

# %% [markdown]
# ### Q10 - A Cable service provider company is interested in checking whether or not the customer churn depends on customer segment. Use 5% as level of significance.
# (2 Marks)

# %% [markdown]
# | Customer Segment | Churned | Retained |
# |  -------- | ----- | ---- |
# | S1 | 15 | 142 |
# | S2 | 24 | 400 |
# | S3 | 30 | 389 |

# %%
Cust_array = np.array([[15,142],[24, 400],[30, 389]])
chistat, pvalue, degfreedom, exp_freq = stats.chi2_contingency(Cust_array)
print(pvalue)
# Out:
# 0.24907816314986156

# %%
print("Since pvalue is greater than 5% (0.05), it is accepted as Alternate Hypothesis - Customer Churn is NOT dependent on Customer Segment")
# Out:
# Since pvalue is greater than 5% (0.05), it is accepted as Alternate Hypothesis - Customer Churn is NOT dependent on Customer Segment

# %% [markdown]
# ## -------------------------------------- End of Test --------------------------------------
